# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import norm
import seaborn as sns

wine_testing=pd.read_csv('C:\\Users\\assharma\\Downloads\\winequality-red.csv')
wine_testing
# Out:
#      Dummy  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     Wine            7.4             0.700         0.00             1.9
# 1     Wine            7.8             0.880         0.00             2.6
# 2     Wine            7.8             0.760         0.04             2.3
# 3     Wine           11.2             0.280         0.56             1.9
# 4     Wine            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1594  Wine            6.2             0.600         0.08             2.0
# 1595  Wine            5.9             0.550         0.10             2.2
# 1596  Wine            6.3             0.510         0.13             2.3
# 1597  Wine            5.9             0.645         0.12             2.0
# 1598  Wine            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    Ph  \
# ...

# %%
wine_testing.columns=map(str.upper,wine_testing.columns)
wine_testing['DUMMY']=wine_testing['DUMMY'].str.upper()
wine_testing.rename(columns={'FREE SULFUR DIOXIDE':'FRF_SULF_DIX','TOTAL SULFUR DIOXIDE':'TOT_SULF_DIX'},inplace=True)

wine_testing
# Out:
#      DUMMY  FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  \
# 0     WINE            7.4             0.700         0.00             1.9
# 1     WINE            7.8             0.880         0.00             2.6
# 2     WINE            7.8             0.760         0.04             2.3
# 3     WINE           11.2             0.280         0.56             1.9
# 4     WINE            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1594  WINE            6.2             0.600         0.08             2.0
# 1595  WINE            5.9             0.550         0.10             2.2
# 1596  WINE            6.3             0.510         0.13             2.3
# 1597  WINE            5.9             0.645         0.12             2.0
# 1598  WINE            6.0             0.310         0.47             3.6
#
#       CHLORIDES  FRF_SULF_DIX  TOT_SULF_DIX  DENSITY    PH  SULPHATES  \
# ...

# %%
wine_testing[wine_testing.isnull().values]
# Out:
#     DUMMY  FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  \
# 6    WINE            7.9              0.60          NaN             1.6
# 6    WINE            7.9              0.60          NaN             1.6
# 7    WINE            7.3              0.65         0.00             1.2
# 7    WINE            7.3              0.65         0.00             1.2
# 9    WINE            7.5              0.50         0.36             6.1
# 10   WINE            6.7              0.58         0.08             1.8
# 11   WINE            7.5              0.50         0.36             6.1
# 15   WINE            8.9              0.62         0.19             3.9
# 19   WINE            7.9               NaN         0.51             1.8
# 112  WINE            8.4              0.60         0.10             2.2
# 113  WINE           10.1              0.31         0.44             2.3
# 114  WINE            7.8              0.56         0.19             1.8
# ...

# %%
wine_testing.isnull().sum()
# Out:
# DUMMY               0
# FIXED ACIDITY       0
# VOLATILE ACIDITY    1
# CITRIC ACID         1
# RESIDUAL SUGAR      0
# CHLORIDES           7
# FRF_SULF_DIX        0
# TOT_SULF_DIX        0
# DENSITY             5
# PH                  0
# SULPHATES           1
# ALCOHOL             0
# QUALITY             0
# dtype: int64

# %%
wine_testing.fillna(wine_testing.mean(),inplace=True)

# %%
wine_testing[wine_testing['FRF_SULF_DIX']==15]
# Out:
#      DUMMY  FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  \
# 2     WINE            7.8             0.760     0.040000             2.3
# 6     WINE            7.9             0.600     0.271108             1.6
# 7     WINE            7.3             0.650     0.000000             1.2
# 10    WINE            6.7             0.580     0.080000             1.8
# 32    WINE            8.3             0.655     0.120000             2.3
# ...    ...            ...               ...          ...             ...
# 1555  WINE            7.0             0.560     0.170000             1.7
# 1557  WINE            6.6             0.855     0.020000             2.4
# 1569  WINE            6.2             0.510     0.140000             1.9
# 1571  WINE            6.4             0.380     0.140000             2.2
# 1573  WINE            6.0             0.580     0.200000             2.4
#
#       CHLORIDES  FRF_SULF_DIX  TOT_SULF_DIX   DENSITY    PH  SULPHATES  \
# ...

# %%
wine_testing.isnull().sum()
# Out:
# DUMMY               0
# FIXED ACIDITY       0
# VOLATILE ACIDITY    0
# CITRIC ACID         0
# RESIDUAL SUGAR      0
# CHLORIDES           0
# FRF_SULF_DIX        0
# TOT_SULF_DIX        0
# DENSITY             0
# PH                  0
# SULPHATES           0
# ALCOHOL             0
# QUALITY             0
# dtype: int64

# %%
wine_testing.describe()
# Out:
#        FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527951     0.271108        2.538806
# std         1.741096          0.178984     0.194730        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          CHLORIDES  FRF_SULF_DIX  TOT_SULF_DIX      DENSITY           PH  \
# count  1599.000000   1599.000000   1599.000000  1599.000000  1599.000000
# mean      0.087419     15.874922     46.467792     0.996747     3.311113
# std       0.047017     10.460157     32.895324     0.001886     0.154386
# ...

# %%
wine_testing.loc[wine_testing['CITRIC ACID']==0.0,'CITRIC ACID']=np.NAN

# %%
wine_testing.describe()
# Out:
#        FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  \
# count    1599.000000       1599.000000  1467.000000     1599.000000
# mean        8.319637          0.527951     0.295502        2.538806
# std         1.741096          0.178984     0.184717        1.409928
# min         4.600000          0.120000     0.010000        0.900000
# 25%         7.100000          0.390000     0.140000        1.900000
# 50%         7.900000          0.520000     0.280000        2.200000
# 75%         9.200000          0.640000     0.440000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          CHLORIDES  FRF_SULF_DIX  TOT_SULF_DIX      DENSITY           PH  \
# count  1599.000000   1599.000000   1599.000000  1599.000000  1599.000000
# mean      0.087419     15.874922     46.467792     0.996747     3.311113
# std       0.047017     10.460157     32.895324     0.001886     0.154386
# ...

# %%
wine_testing.isnull().sum()
# Out:
# DUMMY                 0
# FIXED ACIDITY         0
# VOLATILE ACIDITY      0
# CITRIC ACID         132
# RESIDUAL SUGAR        0
# CHLORIDES             0
# FRF_SULF_DIX          0
# TOT_SULF_DIX          0
# DENSITY               0
# PH                    0
# SULPHATES             0
# ALCOHOL               0
# QUALITY               0
# dtype: int64

# %%
wine_testing.fillna(wine_testing.mean(),inplace=True)

# %%
wine_testing.describe()
# Out:
#        FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527951     0.295502        2.538806
# std         1.741096          0.178984     0.176924        1.409928
# min         4.600000          0.120000     0.010000        0.900000
# 25%         7.100000          0.390000     0.150000        1.900000
# 50%         7.900000          0.520000     0.295502        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          CHLORIDES  FRF_SULF_DIX  TOT_SULF_DIX      DENSITY           PH  \
# count  1599.000000   1599.000000   1599.000000  1599.000000  1599.000000
# mean      0.087419     15.874922     46.467792     0.996747     3.311113
# std       0.047017     10.460157     32.895324     0.001886     0.154386
# ...
