# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats

wine_testing=pd.read_csv('C:\\Users\\assharma\\Downloads\\winequality-red.csv')
wine_testing
# Out:
#      Dummy  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     Wine            7.4             0.700         0.00             1.9
# 1     Wine            7.8             0.880         0.00             2.6
# 2     Wine            7.8             0.760         0.04             2.3
# 3     Wine           11.2             0.280         0.56             1.9
# 4     Wine            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1594  Wine            6.2             0.600         0.08             2.0
# 1595  Wine            5.9             0.550         0.10             2.2
# 1596  Wine            6.3             0.510         0.13             2.3
# 1597  Wine            5.9             0.645         0.12             2.0
# 1598  Wine            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    Ph  \
# ...

# %%
wine_testing.dropna()
wine_testing.drop(['Dummy'],axis=1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.scatterplot(x="chlorides",y="density",hue="quality",data=wine_testing)

# %%
sns.catplot(x="chlorides",y="density",hue="quality",kind="box",data=wine_testing)

# %%
wine_testing.boxplot()

# %%
sns.pairplot(wine_testing)
# Out:
# C:\Users\assharma\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\assharma\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.distplot(wine_testing["quality"],hist=False, bins=50)

# %% [markdown]
# ## Z SCORE METHOD

# %%
z=np.abs(stats.zscore(wine_testing.drop(['Dummy'],axis=1)))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  14,   15,   15,   33,   45,   57,   95,  109,  142,  144,  151,
#         163,  164,  243,  244,  274,  324,  325,  347,  354,  374,  381,
#         391,  396,  396,  400,  400,  442,  459,  467,  480,  494,  515,
#         517,  544,  554,  555,  557,  584,  588,  591,  595,  636,  649,
#         649,  651,  652,  652,  652,  672,  684,  690,  695,  821,  832,
#         899,  911,  917,  923,  925,  926,  982, 1043, 1071, 1074, 1079,
#        1079, 1081, 1081, 1111, 1131, 1154, 1175, 1186, 1231, 1235, 1244,
#        1244, 1244, 1269, 1270, 1295, 1296, 1299, 1300, 1316, 1321, 1358,
#        1374, 1434, 1434, 1435, 1435, 1469, 1474, 1474, 1476, 1476, 1478,
#        1493, 1496, 1505, 1558, 1574, 1589], dtype=int64), array([ 5,  5,  6,  3,  8,  5,  8,  6, 10, 10,  8,  3,  3,  0,  0,  3,  3,
#         3,  0,  6,  0,  0,  0,  3,  5,  3,  5,  0, 11, 10,  3,  3,  6, 11,
#         0,  0,  0,  0,  5, 10,  6,  3,  6,  3,  6,  6,  0,  3, 10,  6,  6,
# ...

# %%
print(z[1558][0])
# Out:
# 0.8156248341507949

# %% [markdown]
# ## IQR Method

# %%
Q1=wine_testing.quantile(0.25)
Q3=wine_testing.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# fixed acidity            2.100000
# volatile acidity         0.250000
# citric acid              0.330000
# residual sugar           0.700000
# chlorides                0.020000
# free sulfur dioxide     14.000000
# total sulfur dioxide    40.000000
# density                  0.002247
# Ph                       0.190000
# sulphates                0.180000
# alcohol                  1.600000
# quality                  1.000000
# dtype: float64

# %%
print(wine_testing<(Q1 - 1.5 * IQR))|(wine_testing > (Q3 + 1.5 * IQR))
# Out:
#       Dummy     Ph  alcohol  chlorides  citric acid  density  fixed acidity  \
# 0     False  False    False      False        False    False          False
# 1     False  False    False      False        False    False          False
# 2     False  False    False      False        False    False          False
# 3     False  False    False      False        False    False          False
# 4     False  False    False      False        False    False          False
# ...     ...    ...      ...        ...          ...      ...            ...
# 1594  False  False    False      False        False    False          False
# 1595  False  False    False      False        False    False          False
# 1596  False  False    False      False        False    False          False
# 1597  False  False    False      False        False    False          False
# 1598  False  False    False      False        False    False          False
#
# ...
